# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import altair as alt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn import set_config

# %%
# Load a CSV file named 'data.csv' into a DataFrame
items = pd.read_csv('items.csv')
sales = pd.read_csv('sales.csv')

print(items.head())
print(sales.head())
# Out:
#     item_name  price  production_cost item_type drink_temperature drink_type
# 0    Espresso   3.00             0.80     Drink               Hot     Coffee
# 1   Americano   3.50             1.00     Drink               Hot     Coffee
# 2       Latte   4.50             1.20     Drink               Hot     Coffee
# 3  Cappuccino   4.25             1.15     Drink               Hot     Coffee
# 4  Flat White   4.75             1.25     Drink               Hot     Coffee
#          date      time    item_name transaction_type own_cup  surcharge  \
# 0  2022-01-01  07:03:30    Cold Brew          Takeout    True      False
# 1  2022-01-01  07:30:58  Iced Coffee          Takeout    True      False
# 2  2022-01-01  08:32:23   Iced Latte          Takeout   False      False
# 3  2022-01-01  08:45:03        Latte          Dine-in    True      False
# 4  2022-01-01  09:03:47        Latte          Takeout   False      False
#
#    customer_id
# 0        26946
# 1        24356
# 2         3760
# ...

# %%
total_data = pd.merge(sales,items,on = "item_name")
total_data.assign(date = pd.to_datetime(total_data["date"] + " " + total_data["time"]))

profit_day = quant_data.groupby("date", freq = "M").sum().reset_index()
profit_day = profit_day.assign(profit = profit_day["price"] - profit_day["production_cost"])
profit_time = alt.Chart(profit_day).mark_line().encode(
    x = alt.X("date:T").title("Date"),
    y = alt.Y("profit").title("Profit ($)")
)
profit_time
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 total_data = pd.merge(sales,items,on = "item_name")
#       2 total_data.assign(date = pd.to_datetime(total_data["date"] + " " + total_data["time"]))
# ----> 4 profit_day = quant_data.groupby("date", freq = "M").sum().reset_index()
#       5 profit_day = profit_day.assign(profit = profit_day["price"] - profit_day["production_cost"])
#       6 profit_time = alt.Chart(profit_day).mark_line().encode(
#       7     x = alt.X("date:T").title("Date"),
#       8     y = alt.Y("profit").title("Profit ($)")
#       9 )
#
# TypeError: DataFrame.groupby() got an unexpected keyword argument 'freq'
